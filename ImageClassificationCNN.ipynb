# %% [markdown]
# <a href="https://colab.research.google.com/github/AnshuYadav07/ImageeClassificationCNN/blob/main/ImageClassificationCNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical

# Load CIFAR-10 dataset
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# Normalize pixel values
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# One-hot encode labels
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Data Augmentation
datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True
)
datagen.fit(x_train)

# Define CNN model
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(32, 32, 3)),
    BatchNormalization(),
    Conv2D(32, (3, 3), activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling2D((2, 2)),
    Dropout(0.3),

    Conv2D(64, (3, 3), activation='relu', padding='same'),
    BatchNormalization(),
    Conv2D(64, (3, 3), activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling2D((2, 2)),
    Dropout(0.4),

    Conv2D(128, (3, 3), activation='relu', padding='same'),
    BatchNormalization(),
    Conv2D(128, (3, 3), activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling2D((2, 2)),
    Dropout(0.5),

    Flatten(),
    Dense(256, activation='relu'),
    BatchNormalization(),
    Dropout(0.5),
    Dense(10, activation='softmax')
])

# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Learning Rate Scheduler
lr_reduction = ReduceLROnPlateau(monitor='val_accuracy',
                                 patience=3,
                                 factor=0.5,
                                 min_lr=1e-5,
                                 verbose=1)

# Train the model with data augmentation
history = model.fit(datagen.flow(x_train, y_train, batch_size=64),
                    epochs=50,
                    validation_data=(x_test, y_test),
                    callbacks=[lr_reduction])

# Evaluate the model
test_loss, test_accuracy = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")
# Out:
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 477s 602ms/step - accuracy: 0.3031 - loss: 2.2421 - val_accuracy: 0.4909 - val_loss: 1.4613 - learning_rate: 0.0010
# Epoch 2/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 486s 582ms/step - accuracy: 0.5097 - loss: 1.3551 - val_accuracy: 0.5814 - val_loss: 1.1965 - learning_rate: 0.0010
# Epoch 3/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 507s 589ms/step - accuracy: 0.5937 - loss: 1.1360 - val_accuracy: 0.6283 - val_loss: 1.0641 - learning_rate: 0.0010
# Epoch 4/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 458s 585ms/step - accuracy: 0.6468 - loss: 1.0011 - val_accuracy: 0.6510 - val_loss: 1.0217 - learning_rate: 0.0010
# Epoch 5/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━
50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 503s 586ms/step - accuracy: 0.8149 - loss: 0.5400 - val_accuracy: 0.8183 - val_loss: 0.5551 - learning_rate: 2.5000e-04
# Epoch 22/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 507s 593ms/step - accuracy: 0.8161 - loss: 0.5310 - val_accuracy: 0.8398 - val_loss: 0.4682 - learning_rate: 2.5000e-04
# Epoch 23/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 501s 591ms/step - accuracy: 0.8203 - loss: 0.5248 - val_accuracy: 0.8396 - val_loss: 0.4834 - learning_rate: 2.5000e-04
# Epoch 24/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 464s 593ms/step - accuracy: 0.8202 - loss: 0.5236 - val_accuracy: 0.8262 - val_loss: 0.5272 - learning_rate: 2.5000e-04
# Epoch 25/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 570ms/step - accuracy: 0.8250 - loss: 0.5140
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 503s 593ms/step - accuracy: 0.8250 - loss: 0.5140 - val_accuracy: 0.8393 - val_loss: 0.4827 - learning_rate: 2.5000e-04
# Epoch 26/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 460s 588ms/step - accuracy: 0.8278 - loss: 0.4994 - val_accuracy: 0.8441 - val_loss: 0.4644 - learning_rate: 1.2500e-04
# Epoch 27/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 498s 583ms/step - accuracy: 0.8274 - loss: 0.4988 - val_accuracy: 0.8466 - val_loss: 0.4596 - learning_rate: 1.2500e-04
# Epoch 28/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 462s 590ms/step - accuracy: 0.8242 - loss: 0.5021 - val_accuracy: 0.8554 - val_loss: 0.4410 - learning_rate: 1.2500e-04
# Epoch 29/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 459s 586ms/step - accuracy: 0.8290 - loss: 0.4981 - val_accuracy: 0.8419 - val_loss: 0.4668 - learning_rate: 1.2500e-04
# Epoch 30/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 468s 598ms/step - accuracy: 0.8302 - loss: 0.4948 - val_accuracy: 0.8460 - val_loss: 0.4639 - learning_rate: 1.2500e-04
# Epoch 31/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 571ms/step - accuracy: 0.8274 - loss: 0.5008
# Epoch 31: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 466s 595ms/step - accuracy: 0.8274 - loss: 0.5008 - val_accuracy: 0.8403 - val_loss: 0.4781 - learning_rate: 1.2500e-04
# Epoch 32/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 461s 589ms/step - accuracy: 0.8366 - loss: 0.4785 - val_accuracy: 0.8478 - val_loss: 0.4586 - learning_rate: 6.2500e-05
# Epoch 33/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 459s 586ms/step - accuracy: 0.8298 - loss: 0.4890 - val_accuracy: 0.8487 - val_loss: 0.4506 - learning_rate: 6.2500e-05
# Epoch 34/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 563ms/step - accuracy: 0.8294 - loss: 0.4879
# Epoch 34: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 460s 588ms/step - accuracy: 0.8294 - loss: 0.4879 - val_accuracy: 0.8529 - val_loss: 0.4408 - learning_rate: 6.2500e-05
# Epoch 35/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 503s 588ms/step - accuracy: 0.8374 - loss: 0.4772 - val_accuracy: 0.8497 - val_loss: 0.4518 - learning_rate: 3.1250e-05
# Epoch 36/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 501s 587ms/step - accuracy: 0.8347 - loss: 0.4818 - val_accuracy: 0.8507 - val_loss: 0.4502 - learning_rate: 3.1250e-05
# Epoch 37/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 565ms/step - accuracy: 0.8336 - loss: 0.4765
# Epoch 37: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 461s 590ms/step - accuracy: 0.8336 - loss: 0.4765 - val_accuracy: 0.8485 - val_loss: 0.4545 - learning_rate: 3.1250e-05
# Epoch 38/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 507s 648ms/step - accuracy: 0.8374 - loss: 0.4756 - val_accuracy: 0.8515 - val_loss: 0.4520 - learning_rate: 1.5625e-05
# Epoch 39/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 520s 593ms/step - accuracy: 0.8371 - loss: 0.4757 - val_accuracy: 0.8523 - val_loss: 0.4452 - learning_rate: 1.5625e-05
# Epoch 40/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 563ms/step - accuracy: 0.8373 - loss: 0.4738
# Epoch 40: ReduceLROnPlateau reducing learning rate to 1e-05.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 498s 588ms/step - accuracy: 0.8373 - loss: 0.4738 - val_accuracy: 0.8528 - val_loss: 0.4459 - learning_rate: 1.5625e-05
# Epoch 41/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 502s 588ms/step - accuracy: 0.8361 - loss: 0.4750 - val_accuracy: 0.8528 - val_loss: 0.4458 - learning_rate: 1.0000e-05
# Epoch 42/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 494s 578ms/step - accuracy: 0.8371 - loss: 0.4699 - val_accuracy: 0.8505 - val_loss: 0.4521 - learning_rate: 1.0000e-05
# Epoch 43/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 504s 581ms/step - accuracy: 0.8440 - loss: 0.4600 - val_accuracy: 0.8537 - val_loss: 0.4428 - learning_rate: 1.0000e-05
# Epoch 44/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 502s 581ms/step - accuracy: 0.8374 - loss: 0.4702 - val_accuracy: 0.8523 - val_loss: 0.4452 - learning_rate: 1.0000e-05
# Epoch 45/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 501s 580ms/step - accuracy: 0.8375 - loss: 0.4642 - val_accuracy: 0.8519 - val_loss: 0.4460 - learning_rate: 1.0000e-05
# Epoch 46/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 452s 578ms/step - accuracy: 0.8393 - loss: 0.4674 - val_accuracy: 0.8540 - val_loss: 0.4418 - learning_rate: 1.0000e-05
# Epoch 47/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 457s 583ms/step - accuracy: 0.8397 - loss: 0.4663 - val_accuracy: 0.8530 - val_loss: 0.4455 - learning_rate: 1.0000e-05
# Epoch 48/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 460s 587ms/step - accuracy: 0.8392 - loss: 0.4712 - val_accuracy: 0.8511 - val_loss: 0.4495 - learning_rate: 1.0000e-05
# Epoch 49/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 455s 582ms/step - accuracy: 0.8404 - loss: 0.4661 - val_accuracy: 0.8539 - val_loss: 0.4412 - learning_rate: 1.0000e-05
# Epoch 50/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 456s 583ms/step - accuracy: 0.8388 - loss: 0.4689 - val_accuracy: 0.8545 - val_loss: 0.4431 - learning_rate: 1.0000e-05
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 22s 71ms/step - accuracy: 0.8552 - loss: 0.4403
# Test Accuracy: 85.45%
